# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')

caminho = "/content/drive/MyDrive/Facul/Relatorio.csv"

cm = pd.read_csv (caminho, low_memory=False, sep=';' , encoding="latin-1")

cm.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                  CNPJ                               RazÃ£o Social  \
# 0  16.603.146/0001-61   GCW - TRANSPORTES RODOVIARIOS LTDA. - EPP
# 1  12.061.291/0001-07                   TRANSPORTADORA BILAC LTDA
# 2  22.611.457/0001-75            EXPRESSO IGUANA TRANSPORTES LTDA
# 3  18.976.884/0001-80     TRANS FARMA LOGISTICA PARA SAUDE EIRELI
# 4  97.471.676/0001-03  DISTRIBUIDORA DE COMBUSTÃVEIS SAARA LTDA.
#
#          Estado             MunicÃ­pio   Ano  \
# 0  MINAS GERAIS                  BETIM  2024
# 1         BAHIA                 PIRIPA  2024
# 2     SAO PAULO  SAO BERNARDO DO CAMPO  2024
# 3         GOIAS   APARECIDA DE GOIANIA  2024
# 4        PARANA               CASCAVEL  2024
#
#                                              Produto Quantidade Transportada  \
# 0  Gasolina automotiva ou para outros usos, excet...              800.000,00
# ...
